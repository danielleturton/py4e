# %% [markdown]
# ### Exercise 1

# %%
x = [1, 7, 6, 4, 9]

# %%
#Exercise 1.a
def chop(x):
    del x[0]
    del x[-1]

# %%
chop(x)

# %%
chopped_list = chop(x)
print(chopped_list)
print(x)
# Out:
# None
# [7, 6, 4]

# %%
# Exercise 1.b
def middle(x):
    length = len(x)
    return(x[1:length-1])

# %%
middle(x)
# Out:
# [7, 6, 4]

# %%
print(x)
# Out:
# [1, 7, 6, 4, 9]

# %% [markdown]
# ### Exercise 2
# Problem is when the line doesn't have the date on it

# %%
fhand = open('mbox-problem.txt') 
count = 0
for line in fhand:
    words = line.split()
    print('Debug:', words)
    if len(words) == 0 : continue
    if words[0] != 'From' : continue 
    print(words[2])
# Out:
# Debug: ['From', 'stephen.marquard@uct.ac.za']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-def8eb1273ff> in <module>()
#       6     if len(words) == 0 : continue
#       7     if words[0] != 'From' : continue
# ----> 8     print(words[2])
#
# IndexError: list index out of range

# %%
fhand = open('mbox-problem.txt') 
count = 0
for line in fhand:
    words = line.split()
    #print('Debug:', words)
    if len(words) < 3 : continue
    if words[0] != 'From' : continue 
    print(words[2])
# Out:
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Tue
# Tue
# Mon
# Mon
# Mon
# Mon
# Mon
# Mon
# Mon
# Sun
# Sun
# Sun
# Sun
# Sun
# Sun
# Sun
# Sat
# Sat
# Sat
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Wed
# Wed
# Wed
# Tue
# Mon
# Mon
# Sun
# Sat
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# ...

# %% [markdown]
# ### Exercise 3

# %%
fhand = open('mbox-problem.txt') 
count = 0
for line in fhand:
    words = line.split()
    #print('Debug:', words)
    if len(words) < 3 or  words[0] != 'From' : continue
    print(words[2])
# it's told me to use 'and' not 'or' but this works for what I've done
# Out:
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Wed
# Tue
# Tue
# Mon
# Mon
# Mon
# Mon
# Mon
# Mon
# Mon
# Sun
# Sun
# Sun
# Sun
# Sun
# Sun
# Sun
# Sat
# Sat
# Sat
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
# Wed
# Wed
# Wed
# Tue
# Mon
# Mon
# Sun
# Sat
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# ...

# %% [markdown]
# ## Exercise 4

# %%
fhand = open('romeo.txt')
t = []
count = 0
for line in fhand :
    # line.lower() #doesn't work, and doesn't work on lists
    words = line.split()
    for word in words :
        if word in t : continue
        t.append(word[count])
        count = count + 1
    words.sort()
    print(words)

# %%
fhand = open('romeo.txt')
t = []
for line in fhand :
    words = line.split()
    for word in words :
        if word in t : continue
        t.append(word)
        t.sort()
print(t)
# Out:
# ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']

# %% [markdown]
# ## Exercise 5

# %%
fhand = open('mbox-short.txt') 
count = 0
for line in fhand:
    words = line.split()
    #print('Debug:', words)
    if len(words) < 3 or  words[0] != 'From' : continue
    count = count + 1
    print(words[1])
print('There were', count,'lines of addressees')
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# There were 27 lines of addressees

# %% [markdown]
# ### Exercise 6

# %%
t = []
while True :
    value = input('gimme a number\n')
    if value == 'done':
        break
    try: 
        value = float(value)
        t.append(value)
    except :
        print('I said number you fool')
new_list = []
for item in t:
    new_list.append(float(item))
print('There are', len(new_list), 'items in your list.  The highest is', max(new_list), 
      'and the lowest is', min(new_list))
# Out:
# gimme a number
# 1
# gimme a number
# hello
# I said number you fool
# gimme a number
# 10
# gimme a number
# 12
# gimme a number
# 34
# gimme a number
# done
# There are 4 items in your list.  The highest is 34.0 and the lowest is 1.0
